# %%
import pandas as pd
from estatisticas import dict_faturamento as faturamento

# %%
df_faturamento = pd.DataFrame.from_dict(faturamento)

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
df_faturamento.rename(columns={"data_ref":"data"}, inplace=True)

# %%
df_faturamento["data"] = pd.to_datetime(df_faturamento["data"],format="ISO8601")

# %%
df_faturamento
# Out:
#          data   valor
# 0  2023-01-01  400000
# 1  2020-02-01  890000
# 2  2021-03-01  760000
# 3  2022-04-01  430000
# 4  2023-05-01  920000
# 5  2023-06-01  340000
# 6  2020-07-01  800000
# 7  2021-08-01  500000
# 8  2022-09-01  200000
# 9  2023-10-01  900000
# 10 2022-11-01  570000
# 11 2023-12-01  995000

# %%
df_faturamento.plot.line(x="data",y="valor",color="green")
# Out:
# <Axes: xlabel='data'>

# %%
df_faturamento.plot.bar(x="data",y="valor")
# Out:
# <Axes: xlabel='data'>

# %%
round(df_faturamento["valor"].mean(),2)
# Out:
# np.float64(642083.33)
